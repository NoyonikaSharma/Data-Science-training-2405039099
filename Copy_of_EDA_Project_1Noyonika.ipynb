# %% [markdown]
# <a href="https://colab.research.google.com/github/NoyonikaSharma/Data-Science-training-2405039099/blob/main/Copy_of_EDA_Project_1Noyonika.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Course Project Guidelines**
#
#
# ### Evaluation Criteria
#
# Your submission will be evaluated using the following criteria:
#
# * Dataset must contain at least 3 columns and 150 rows of data
# * You must ask and answer at least 5 questions about the dataset
# * Your submission must include at least 5 visualizations (graphs)
# * Your submission must include explanations using markdown cells, apart from the code.
# * Your work must not be plagiarized i.e. copy-pasted for somewhere else.
#
#
# Follow this step-by-step guide to work on your project.
#
#
# ### Step 1: Select a real-world dataset
#
# - Find an interesting dataset on this page: https://www.kaggle.com/datasets?fileType=csv
# - The data should be in CSV format, and should contain at least 3 columns and 150 rows
# - Download the dataset using the [`opendatasets` Python library](https://github.com/JovianML/opendatasets#opendatasets)
#
# Here's some sample code for downloading the [US Elections Dataset](https://www.kaggle.com/tunguz/us-elections-dataset):
#
# ```
# import opendatasets as od
# dataset_url = 'https://www.kaggle.com/tunguz/us-elections-dataset'
# od.download('https://www.kaggle.com/tunguz/us-elections-dataset')
# ```
#
# ### Step 2: Perform data preparation & cleaning
#
# - Load the dataset into a data frame using Pandas
# - Explore the number of rows & columns, ranges of values etc.
# - Handle missing, incorrect and invalid data
# - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)
#
#
# ### Step 3: Perform exploratory analysis & visualization
#
# - Compute the mean, sum, range and other interesting statistics for numeric columns
# - Explore distributions of numeric columns using histograms etc.
# - Explore relationship between columns using scatter plots, bar charts etc.
# - Make a note of interesting insights from the exploratory analysis
#
# ### Step 4: Ask & answer questions about the data
#
# - Ask at least 5 interesting questions about your dataset
# - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does
#
#
# ### Step 5: Summarize your inferences & write a conclusion
#
# - Write a summary of what you've learned from the analysis
# - Include interesting insights and graphs from previous sections
# - Share ideas for future work on the same topic using other relevant datasets
# - Share links to resources you found useful during your analysis
#
#
# ### Step 6: Make a submission & share your work

# %% [markdown]
# # **CAR MARKET ANALYSIS PROJECT**

# %%
import pandas as pd
cars_df = pd.read_csv('/content/quikr_car.csv')
cars_df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %% [markdown]
# # **Cleaning of the whole data**

# %%
import pandas as pd

# Load dataset
cars_df = pd.read_csv("quikr_car.csv")

# -------------------------------
# Clean Year
# -------------------------------
cars_df = cars_df[cars_df['year'].astype(str).str.isnumeric()]
cars_df['year'] = cars_df['year'].astype(int)

# -------------------------------
# Clean Price
# -------------------------------
cars_df = cars_df[cars_df['Price'] != 'Ask For Price']

cars_df['Price'] = (
    cars_df['Price']
    .astype(str)
    .str.replace(',', '', regex=False)
)

cars_df['Price'] = pd.to_numeric(cars_df['Price'])

# -------------------------------
# Clean Kilometers Driven
# -------------------------------
cars_df = cars_df[cars_df['kms_driven'].notna()]

cars_df['kms_driven'] = (
    cars_df['kms_driven']
    .astype(str)
    .str.replace(' kms', '', regex=False)
    .str.replace(',', '', regex=False)
)

cars_df = cars_df[cars_df['kms_driven'].str.isnumeric()]
cars_df['kms_driven'] = cars_df['kms_driven'].astype(int)

# -------------------------------
# Clean Fuel Type
# -------------------------------
cars_df = cars_df[cars_df['fuel_type'].notna()]

# -------------------------------
# Remove Duplicates
# -------------------------------
cars_df.drop_duplicates(inplace=True)

# -------------------------------
# Reset Index
# -------------------------------
cars_df.reset_index(drop=True, inplace=True)

# -------------------------------
# Check Final Dataset
# -------------------------------
print(cars_df.info())
print(cars_df.head())
print(cars_df.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 724 entries, 0 to 723
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        724 non-null    object
#  1   company     724 non-null    object
#  2   year        724 non-null    int64
#  3   Price       724 non-null    int64
#  4   kms_driven  724 non-null    int64
#  5   fuel_type   724 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 34.1+ KB
# None
#                                      name   company  year   Price  kms_driven  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000       45000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006  425000          40
# 2  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000       28000
# 3        Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000       36000
# 4                               Ford Figo      Ford  2012  175000       41000
#
# ...

# %%
cars_df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 719              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 720               Tata Indica V2 DLE BS III      Tata  2009  110000
# 721                    Toyota Corolla Altis    Toyota  2009  300000
# 722                     Tata Zest XM Diesel      Tata  2018  260000
# 723                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 2         28000    Petrol
# 3         36000    Diesel
# ...

# %% [markdown]
# **Question 1:**
#
# Which car companies have the highest average selling price?

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

company_price = cars_df.groupby('company')['Price'].mean().sort_values(ascending=False).head(10)

company_price.plot(
    kind='bar',
    figsize=(10,5),
    color='#1F4E79'
)

plt.title('Top 10 Companies by Average Price')
plt.xlabel('Company')
plt.ylabel('Average Price (₹)')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Ques2**. How has average car price changed over manufacturing years?

# %%
year_price = cars_df.groupby('year')['Price'].mean()

year_price.plot(
    kind='line',
    figsize=(10,5),
    color='#1F4E79',
    marker='o'
)

plt.title('Average Price by Manufacturing Year')
plt.xlabel('Year')
plt.ylabel('Average Price (₹)')

plt.show()

# %% [markdown]
# **Ques 3**. Compare average price and number of listings by company

# %%
company_count = cars_df['company'].value_counts().head(10)

company_avg_price = (
    cars_df.groupby('company')['Price']
    .mean()
    .loc[company_count.index]
)

fig, ax1 = plt.subplots(figsize=(10,5))

ax1.bar(
    company_count.index,
    company_count.values,
    color='#1F4E79'
)

ax1.set_ylabel('Number of Listings')

ax2 = ax1.twinx()

ax2.plot(
    company_avg_price.index,
    company_avg_price.values,
    color='orange',
    marker='o'
)

ax2.set_ylabel('Average Price')

plt.title('Listings vs Average Price')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# **Ques 4**. What is the market share of each fuel type?

# %%
import matplotlib.pyplot as plt

fuel_counts = cars_df['fuel_type'].value_counts()

# Navy Blue to Light Blue palette
colors = ['#1F4E79', '#2E75B6', '#5B9BD5', '#9DC3E6', '#D9EAF7']

plt.figure(figsize=(6,4))

fuel_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90,
    colors=colors,
    shadow=True,
    wedgeprops={'edgecolor': 'white', 'linewidth': 2},
    textprops={'fontsize': 11, 'fontweight': 'bold'}
)

plt.title(
    'Fuel Type Distribution',
    fontsize=18,
    fontweight='bold',
    pad=20
);

plt.ylabel('')  ;

plt.tight_layout();
plt.show();
# Out:
# /tmp/ipykernel_9696/3312107886.py:29: UserWarning: Glyph 128663 (\N{AUTOMOBILE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout();
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128663 (\N{AUTOMOBILE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# **Ques 5** .What is the correlation between Year, Price and KMs Driven?

# %%
import seaborn as sns

corr = cars_df[
    ['year','Price','kms_driven']
].corr()

plt.figure(figsize=(6,4))

sns.heatmap(
    corr,
    annot=True,
    cmap='Blues'
)

plt.title('Correlation Heatmap')

plt.show()

# %% [markdown]
# **Ques 6** .Does higher mileage affect car price?

# %%
cars_df.plot(
    kind='scatter',
    x='kms_driven',
    y='Price',
    figsize=(8,5),
    color='#1F4E79'
)

plt.title('KMs Driven vs Price')

plt.show()

# %% [markdown]
# # ** Data Cleaning Questions**

# %% [markdown]
# **Ques 7**.Check Missing Values

# %%
cars_df.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %% [markdown]
# **Ques 8** .Check Duplicate Records

# %%
cars_df.duplicated().sum()
cars_df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 719              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 720               Tata Indica V2 DLE BS III      Tata  2009  110000
# 721                    Toyota Corolla Altis    Toyota  2009  300000
# 722                     Tata Zest XM Diesel      Tata  2018  260000
# 723                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 2         28000    Petrol
# 3         36000    Diesel
# ...

# %% [markdown]
# **Ques 9** .Remove duplicates

# %%
cars_df.drop_duplicates(inplace=True)
cars_df
# Out:
#                                        name   company  year   Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007   80000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  425000
# 2    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  325000
# 3          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  575000
# 4                                 Ford Figo      Ford  2012  175000
# ..                                      ...       ...   ...     ...
# 719              Maruti Suzuki Ritz VXI ABS    Maruti  2011  270000
# 720               Tata Indica V2 DLE BS III      Tata  2009  110000
# 721                    Toyota Corolla Altis    Toyota  2009  300000
# 722                     Tata Zest XM Diesel      Tata  2018  260000
# 723                      Mahindra Quanto C8  Mahindra  2013  390000
#
#      kms_driven fuel_type
# 0         45000    Petrol
# 1            40    Diesel
# 2         28000    Petrol
# 3         36000    Diesel
# ...

# %% [markdown]
# **Ques 10** . List the most expensive 10 cars ?

# %%
cars_df[
    ['name','company','Price']
].sort_values(
    by='Price',
    ascending=False
).head(10)
# Out:
#                                       name   company    Price
# 447                     Mahindra XUV500 W6  Mahindra  8500003
# 589              Audi A3 Cabriolet 40 TFSI      Audi  3100000
# 681         Ford Endeavor 4x4 Thunder Plus      Ford  2900000
# 398                 Jaguar XE XE Portfolio    Jaguar  2800000
# 538   Audi Q5 2.0 TDI quattro Premium Plus      Audi  2390000
# 537            Jaguar XF 2.2 Diesel Luxury    Jaguar  2190000
# 189             Land Rover Freelander 2 SE      Land  2100000
# 188  Mercedes Benz GLA Class 200 CDI Sport  Mercedes  2000000
# 548         Audi A4 2.0 TDI 177bhp Premium      Audi  1900000
# 52                       Mini Cooper S 1.6      Mini  1891111
